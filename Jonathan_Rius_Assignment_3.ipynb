# %% [markdown]
# <a href="https://colab.research.google.com/github/jonnie763/DATA-690-WANG/blob/master/Jonathan_Rius_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Write a program that generates 100 random integers between 0 and 9.*
#
# **1. Print them in a 10 by 10 matrix neatly arranged like the following (one space between each number)**
#
# **2.If the random number is an odd number, print "@" instead. like the following**
#
# **3.Calculate and Print the total of each row like the following (use "*" to separate the total from the numbers)**

# %%
# For the first part I used a random number generator with 10 numbers from 0 to 9, however I was able to include the replacements for odd numbers later (but not in a ten by ten matrix) 

import random
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
sum(x)
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
x = []
for i in range(10):
    x.append(random.randint(0,9))     
print(x,"*",sum(x))
# Out:
# [6, 2, 4, 3, 8, 1, 2, 6, 9, 1] * 42
# [0, 6, 0, 0, 6, 9, 6, 2, 0, 7] * 36
# [7, 0, 1, 0, 8, 8, 9, 3, 8, 0] * 44
# [6, 4, 2, 8, 5, 4, 5, 8, 8, 7] * 57
# [9, 5, 2, 6, 0, 3, 8, 2, 9, 5] * 49
# [1, 7, 4, 3, 0, 6, 0, 7, 9, 9] * 46
# [5, 0, 0, 4, 6, 2, 7, 0, 0, 9] * 33
# [9, 6, 3, 1, 8, 2, 4, 9, 5, 2] * 49
# [6, 9, 5, 4, 0, 1, 1, 5, 8, 2] * 41
# [3, 8, 5, 5, 2, 9, 3, 4, 1, 1] * 41

# %%
# # With some inquiry I was able to then generate a list of 100 numbers with each odd number being replaced with a "@" symbol. However, the matrix was not a ten by ten matrix but a 1 column singular line.  It does meeet the conditions of the two above except it is not in a ten by ten matrix. 
# If the output was in a ten by ten matrix, it would fulfill all conditions of the asssignment. 
# Any suggestions on creating a ten by ten matrix from here would be very appreciated.  

import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
import random
x = []
for i in range(10):
    x.append(random.randint(0,9))
    if x[i] % 2 == 0:
        print(x[i])
    else:
        print("@")   
print("*",sum(x))
# Out:
# 0
# @
# 2
# 8
# 0
# @
# 6
# 8
# 4
# 4
# * 38
# @
# 0
# 8
# 8
# @
# 0
# 2
# 8
# 0
# @
# * 39
# @
# 8
# 8
# 2
# 0
# @
# @
# 4
# 8
# 2
# * 47
# @
# 0
# 2
# @
# @
# 2
# @
# 8
# @
# @
# * 42
# @
# 2
# 0
# 0
# @
# 8
# 0
# 4
# 6
# 0
# * 24
# 8
# @
# 6
# @
# 0
# @
# 2
# @
# 8
# 4
# * 46
# @
# @
# @
# 0
# @
# @
# 2
# 2
# @
# @
# * 37
# @
# 0
# @
# 0
# 4
# 4
# 8
# 4
# 4
# @
# * 41
# @
# 4
# @
# @
# @
# @
# @
# 2
# @
# 4
# * 49
# @
# 0
# @
# 0
# @
# @
# 6
# @
# 0
# 4
# * 29
