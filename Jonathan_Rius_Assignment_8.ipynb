# %% [markdown]
# <a href="https://colab.research.google.com/github/jonnie763/DATA-690-WANG/blob/master/Jonathan_Rius_Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_html("https://www.baseball-reference.com/players/s/sotoju01.shtml")
df = df[0]
df
# Out:
#             Year            Age  ...    Pos                      Awards
# 0           2016             17  ...    NaN         NAT,AUB · GULF,NYPL
# 1           2017             18  ...    NaN         HGR,NAT · SALL,GULF
# 2           2018             19  ...    NaN  POT,HGR,HRB · CARL,SALL,EL
# 3           2018             19  ...   *7/H                       RoY-2
# 4           2019             20  ...     *7                       MVP-9
# 5           2020             21  ...  *7/9D                          SS
# 6          3 Yrs          3 Yrs  ...    NaN                         NaN
# 7  162 Game Avg.  162 Game Avg.  ...    NaN                         NaN
#
# [8 rows x 30 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import math
from zipfile import ZipFile
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 12, 10

# %%
df["OPS"]
df=df["OPS"]
df
# Out:
# 0    0.973
# 1    0.919
# 2    1.218
# 3    0.923
# 4    0.949
# 5    1.185
# 6    0.972
# 7    0.972
# Name: OPS, dtype: float64

# %%
df=df[3:6]
df
# Out:
# 3    0.923
# 4    0.949
# 5    1.185
# Name: OPS, dtype: float64

# %%
import pandas as pd
df= pd.read_html("https://www.baseball-reference.com/players/m/mantlmi01.shtml")
df = df[0]
df
# Out:
#              Year            Age             Tm  ...  IBB      Pos          Awards
# 0            1949             17        NYY-min  ...  NaN      NaN      INC · KOML
# 1            1950             18        NYY-min  ...  NaN      NaN        JOP · WA
# 2            1951             19        NYY-min  ...  NaN      NaN        KCY · AA
# 3            1951             19            NYY  ...    2     9H/8             NaN
# 4            1952             20            NYY  ...   10   *89/5H        AS,MVP-3
# 5            1953             21            NYY  ...    3  *8/H976       AS,MVP-22
# 6            1954             22            NYY  ...    7  *8/6H49       AS,MVP-15
# 7            1955             23            NYY  ...    6    *8/H6        AS,MVP-5
# 8            1956             24            NYY  ...    6     *8/H        AS,MVP-1
# 9            1957             25            NYY  ...   23     *8/H        AS,MVP-1
# ...

# %%
df["OPS"]
df=df["OPS"]
df
# Out:
# 0      .780
# 1     1.021
# 2     1.096
# 3      .792
# 4      .924
# 5      .895
# 6      .933
# 7     1.042
# 8     1.169
# 9     1.177
# 10    1.035
# 11     .904
# 12     .957
# 13    1.135
# 14    1.091
# 15    1.063
# 16    1.015
# 17     .831
# 18     .927
# 19     .825
# 20     .782
# 21     .977
# 22     .977
# 23      OPS
# Name: OPS, dtype: object

# %%
df=df[3:21]
df
# Out:
# 3      .792
# 4      .924
# 5      .895
# 6      .933
# 7     1.042
# 8     1.169
# 9     1.177
# 10    1.035
# 11     .904
# 12     .957
# 13    1.135
# 14    1.091
# 15    1.063
# 16    1.015
# 17     .831
# 18     .927
# 19     .825
# 20     .782
# Name: OPS, dtype: object

# %%
OPS= list(df) # Listing years for dataframe piviot, take out Country with remove 
OPS
# Out:
# ['.792',
#  '.924',
#  '.895',
#  '.933',
#  '1.042',
#  '1.169',
#  '1.177',
#  '1.035',
#  '.904',
#  '.957',
#  '1.135',
#  '1.091',
#  '1.063',
#  '1.015',
#  '.831',
#  '.927',
#  '.825',
#  '.782']

# %%
import pandas as pd
df= pd.read_html("https://www.baseball-reference.com/players/m/mantlmi01.shtml")
df = df[0]
df
df["Year"]

df2=df["Year"]
df2
# Out:
# 0              1949
# 1              1950
# 2              1951
# 3              1951
# 4              1952
# 5              1953
# 6              1954
# 7              1955
# 8              1956
# 9              1957
# 10             1958
# 11             1959
# 12             1960
# 13             1961
# 14             1962
# 15             1963
# 16             1964
# 17             1965
# 18             1966
# 19             1967
# 20             1968
# 21           18 Yrs
# 22    162 Game Avg.
# 23              NaN
# Name: Year, dtype: object

# %%
df2=df2[3:21]
df2
# Out:
# 3     1951
# 4     1952
# 5     1953
# 6     1954
# 7     1955
# 8     1956
# 9     1957
# 10    1958
# 11    1959
# 12    1960
# 13    1961
# 14    1962
# 15    1963
# 16    1964
# 17    1965
# 18    1966
# 19    1967
# 20    1968
# Name: Year, dtype: object

# %%
YEARS= list(df2) # Listing years for dataframe piviot, take out Country with remove 
YEARS
# Out:
# ['1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968']

# %%
df = pd.DataFrame (columns = [YEARS,OPS])
df
# Out:
# Empty DataFrame
# Columns: [(1951, .792), (1952, .924), (1953, .895), (1954, .933), (1955, 1.042), (1956, 1.169), (1957, 1.177), (1958, 1.035), (1959, .904), (1960, .957), (1961, 1.135), (1962, 1.091), (1963, 1.063), (1964, 1.015), (1965, .831), (1966, .927), (1967, .825), (1968, .782)]
# Index: []

# %%
import pandas as pd

cars = {'YEARS': YEARS,
        'OPS': OPS
        }

df = pd.DataFrame(cars, columns = ['YEARS', 'OPS'])

print (df)
# Out:
#    YEARS    OPS
# 0   1951   .792
# 1   1952   .924
# 2   1953   .895
# 3   1954   .933
# 4   1955  1.042
# 5   1956  1.169
# 6   1957  1.177
# 7   1958  1.035
# 8   1959   .904
# 9   1960   .957
# 10  1961  1.135
# 11  1962  1.091
# 12  1963  1.063
# 13  1964  1.015
# 14  1965   .831
# 15  1966   .927
# 16  1967   .825
# 17  1968   .782

# %%
df
# Out:
#    YEARS    OPS
# 0   1951   .792
# 1   1952   .924
# 2   1953   .895
# 3   1954   .933
# 4   1955  1.042
# 5   1956  1.169
# 6   1957  1.177
# 7   1958  1.035
# 8   1959   .904
# 9   1960   .957
# 10  1961  1.135
# 11  1962  1.091
# 12  1963  1.063
# 13  1964  1.015
# 14  1965   .831
# 15  1966   .927
# 16  1967   .825
# 17  1968   .782

# %%
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEARS   18 non-null     object
#  1   OPS     18 non-null     object
# dtypes: object(2)
# memory usage: 416.0+ bytes

# %%
df=df.astype(float)

# %%
df.plot(kind='bar',x='YEARS',y='OPS')

plt.axhline(y= .78, color='r')

# %%
# Python program to read  
# image using matplotlib 
  
# importing matplotlib modules 
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
  
# Read Images 
img = mpimg.imread('/content/PIC.PNG') 
  
# Output Images 
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-2aec1b9f46e4> in <module>()
#       7
#       8 # Read Images
# ----> 9 img = mpimg.imread('/content/PIC.PNG')
#      10
#      11 # Output Images
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imread(fname, format)
#    1472             fd = BytesIO(request.urlopen(fname).read())
#    1473             return _png.read_png(fd)
# -> 1474     with cbook.open_file_cm(fname, "rb") as file:
#    1475         return _png.read_png(file)
#    1476
#
# /usr/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ...

# %% [markdown]
# ##Just manually input juan soto vs micky mantle on combined bar plot. Make a data frame first then graph them. If that doesn't work do a manual graph and ignore the data frame. Do a bar graph of juan soto hall of fame, and per season using WAR. Do the same for Bryce Harper.

# %%
import pandas as pd
df= pd.read_html("https://www.baseball-reference.com/awards/hof.shtml")
df = df[0]
df
# Out:
#      Year               Name  ...  Votes % of Ballots
# 0    2020        Derek Jeter  ...  396.0        99.7%
# 1    2020      Marvin Miller  ...    NaN          NaN
# 2    2020        Ted Simmons  ...    NaN          NaN
# 3    2020       Larry Walker  ...  304.0        76.6%
# 4    2019      Harold Baines  ...    NaN          NaN
# ..    ...                ...  ...    ...          ...
# 328  1936            Ty Cobb  ...  222.0        98.2%
# 329  1936     Walter Johnson  ...  189.0        83.6%
# 330  1936  Christy Mathewson  ...  205.0        90.7%
# 331  1936          Babe Ruth  ...  215.0        95.1%
# 332  1936       Honus Wagner  ...  215.0        95.1%
#
# [333 rows x 7 columns]

# %%
import pandas as pd
df= pd.read_html("https://www.baseball-reference.com/leaders/WAR_career.shtml")
df = df[0]
df
# Out:
#       Rank     Player (yrs, age) Wins Above Replacement Bats/Throws
# 0       1.       Babe Ruth+ (22)                  182.5           L
# 1       2.  Walter Johnson+ (21)                  164.5           R
# 2       3.        Cy Young+ (22)                  163.8           R
# 3       4.      Barry Bonds (22)                  162.8           L
# 4       5.     Willie Mays+ (22)                  156.2           R
# ...    ...                   ...                    ...         ...
# 1013   NaN   Justin Morneau (14)                   27.0           L
# 1014   NaN     Bill Skowron (14)                   27.0           R
# 1015   NaN         Red Smith (9)                   27.0           R
# 1016  998.     Mike Cuellar (15)                   26.9           L
# 1017   NaN        Vic Wertz (17)                   26.9           L
#
# [1018 rows x 4 columns]

# %%
df=df[df['Player (yrs, age)'].str.contains("\+")]
df
# Out:
#      Rank        Player (yrs, age) Wins Above Replacement Bats/Throws
# 0      1.          Babe Ruth+ (22)                  182.5           L
# 1      2.     Walter Johnson+ (21)                  164.5           R
# 2      3.           Cy Young+ (22)                  163.8           R
# 4      5.        Willie Mays+ (22)                  156.2           R
# 5      6.            Ty Cobb+ (24)                  151.0           L
# ..    ...                      ...                    ...         ...
# 813   NaN        Chick Hafey+ (13)                   31.1           R
# 902   NaN          Lee Smith+ (18)                   28.9           R
# 945  928.     Trevor Hoffman+ (18)                   28.0           R
# 955   NaN        Lloyd Waner+ (18)                   27.9           L
# 979   NaN  Freddie Lindstrom+ (13)                   27.5           R
#
# [237 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237 entries, 0 to 979
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    158 non-null    object
#  1   Player (yrs, age)       237 non-null    object
#  2   Wins Above Replacement  237 non-null    object
#  3   Bats/Throws             237 non-null    object
# dtypes: object(4)
# memory usage: 9.3+ KB

# %%
df['Wins Above Replacement'].astype(float)
df=df['Wins Above Replacement'].astype(float)
df
# Out:
# 0      182.5
# 1      164.5
# 2      163.8
# 4      156.2
# 5      151.0
#        ...
# 813     31.1
# 902     28.9
# 945     28.0
# 955     27.9
# 979     27.5
# Name: Wins Above Replacement, Length: 237, dtype: float64

# %%
df.mean()
# Out:
# 68.32362869198312

# %%
https://www.baseball-reference.com/leaders/WAR_career.shtml

https://www.pythonprogramming.in/how-to-read-specific-columns-of-csv-file-using-pandas.html

# %%
https://davidhamann.de/2017/06/26/pandas-select-elements-by-string/


https://datatofish.com/convert-string-to-float-dataframe/
